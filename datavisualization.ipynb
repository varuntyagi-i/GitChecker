# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
'''   
install local git
s- git config user.name
s- git config user.email

local file -> local git
s- git init
git add . 
git commit -m "<your msg>"

local git -> server (github/gitlab/..)
s- git remote add origin <repo. url>
s- git branch -M main
git push -u origin main
'''

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [10, 14, 8, 20, 12]

# %%
plt.plot(x, y, marker = 'o', linestyle='-', color='b', label='Line Plot' )

plt.xlabel("X-axis")
plt.ylabel('Y-axis')
plt.title('Line Plot Example')
plt.legend()

plt.show()
